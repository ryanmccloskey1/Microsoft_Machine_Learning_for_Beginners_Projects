# %%
#Importing libraries
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, model_selection

# %%
#Importing and looking at the data
X, y = datasets.load_diabetes(return_X_y=True)
print(X.shape)
print(X[0])
# Out:
# (442, 10)
# [ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#  -0.04340085 -0.00259226  0.01990749 -0.01764613]

# %%
#Splitting columns for plotting and creating a 2D array to build the model on one variable
X = X[:, 2]
X = X.reshape((-1,1))

# %%
print(X1)
# Out:
# [[ 0.06169621]
#  [-0.05147406]
#  [ 0.04445121]
#  [-0.01159501]
#  [-0.03638469]
#  [-0.04069594]
#  [-0.04716281]
#  [-0.00189471]
#  [ 0.06169621]
#  [ 0.03906215]
#  [-0.08380842]
#  [ 0.01750591]
#  [-0.02884001]
#  [-0.00189471]
#  [-0.02560657]
#  [-0.01806189]
#  [ 0.04229559]
#  [ 0.01211685]
#  [-0.0105172 ]
#  [-0.01806189]
#  [-0.05686312]
#  [-0.02237314]
#  [-0.00405033]
#  [ 0.06061839]
#  [ 0.03582872]
#  [-0.01267283]
#  [-0.07734155]
#  [ 0.05954058]
#  [-0.02129532]
#  [-0.00620595]
#  [ 0.04445121]
#  [-0.06548562]
#  [ 0.12528712]
#  [-0.05039625]
#  [-0.06332999]
#  [-0.03099563]
#  [ 0.02289497]
#  [ 0.01103904]
#  [ 0.07139652]
#  [ 0.01427248]
#  [-0.00836158]
#  [-0.06764124]
#  [-0.0105172 ]
#  [-0.02345095]
#  [ 0.06816308]
#  [-0.03530688]
#  [-0.01159501]
#  [-0.0730303 ]
#  [-0.04177375]
#  [ 0.01427248]
#  [-0.00728377]
#  [ 0.0164281 ]
#  [-0.00943939]
#  [-0.01590626]
#  [ 0.0250506 ]
#  [-0.04931844]
#  [ 0.04121778]
#  [-0.06332999]
# ...

# %%
#Creating training and test sets
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.3)

# %%
#Building a linear regression model to predict y
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Testing the model by actually predicting y
y_pred = model.predict(X_test)

# %%
#Plotting the data and showing a line to best
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)
plt.xlabel('Scaled BMIs')
plt.ylabel('Disease Progression')
plt.title('A Graph Plot Showing Diabetes Progression Against BMI')
plt.show()

# %%
#Now doing the same with the linnerud data set
X1, y1 = datasets.load_linnerud(return_X_y=True)

# %%
print(X1)
# Out:
# [[  5. 162.  60.]
#  [  2. 110.  60.]
#  [ 12. 101. 101.]
#  [ 12. 105.  37.]
#  [ 13. 155.  58.]
#  [  4. 101.  42.]
#  [  8. 101.  38.]
#  [  6. 125.  40.]
#  [ 15. 200.  40.]
#  [ 17. 251. 250.]
#  [ 17. 120.  38.]
#  [ 13. 210. 115.]
#  [ 14. 215. 105.]
#  [  1.  50.  50.]
#  [  6.  70.  31.]
#  [ 12. 210. 120.]
#  [  4.  60.  25.]
#  [ 11. 230.  80.]
#  [ 15. 225.  73.]
#  [  2. 110.  43.]]

# %%
#Isolating the chins and weight variables as we would expect these to be negatively correlated
X1 = X1[:, 0]
X1 = X1.reshape((-1,1))
                
y1 = y1[:, 0]
y1 = y1.reshape((-1,1))

# %%
#Splitting the dataset into straining and testing
X1_train, X1_test, y1_train, y1_test = model_selection.train_test_split(X1, y1, test_size=0.2)

# %%
#Building a linear regression model to predict weight
model1 = linear_model.LinearRegression()
model1.fit(X1_train, y1_train)
# Out:
# LinearRegression()

# %%
#Testing the model by actually predicting weight
y1_pred = model1.predict(X1_test)

# %%
#Plotting the data and showing a line to best
plt.scatter(X1, y1,  color='black')
plt.plot(X1_test, y1_pred, color='blue', linewidth=3)
plt.xlabel('Chins')
plt.ylabel('Weight')
plt.title('A Graph Plot Showing Weight Against Chins')
plt.show()
